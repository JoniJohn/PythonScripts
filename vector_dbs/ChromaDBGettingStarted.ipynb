# %% [markdown]
# Install Chroma

# %%
# %pip install chromadb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Create Chroma Client

# %%
import chromadb

chroma_client = chromadb.Client()

# %% [markdown]
# ### Create a collection
#
# Collections are where you store your embeddings, documents, and any additional metadata. Collections index your embeddings and documents, and enable efficient retirival and filtering.

# %%
collection = chroma_client.create_collection(name="my_collection")

# %% [markdown]
# ### Add some text documents to the collection
#
# Chroma will store your text and handle embedding and indexing automatically. You can also customize the embedding model. You must provide unique string IDs for your documents.

# %%
collection.add(
    ids=["id1", "id2", "id3", "id4"],
    documents=[
        "This is a document about seswaa",
        "This is a document about bogobe",
        "This is a document about mogodu",
        "This is a document about fish",
    ]
)

# %% [markdown]
# Query the collection

# %%
results = collection.query(
    query_texts=["I want seswaa dishes"],
    n_results=2
)

results
# Out:
# {'ids': [['id1', 'id4']],
#  'embeddings': None,
#  'documents': [['This is a document about seswaa',
#    'This is a document about fish']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.0015286207199097, 1.675697922706604]]}
